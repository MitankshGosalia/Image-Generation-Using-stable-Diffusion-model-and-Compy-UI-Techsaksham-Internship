# %%
# Install necessary libraries
# !pip install torch torchvision torchaudio
# !pip install diffusers
# !pip install streamlit
# !pip install streamlit-diffusion
# !pip install comfyui
# !pip install transformers
# !pip install datasets

# %%
# Import necessary libraries
import torch
from diffusers import StableDiffusionPipeline, StableDiffusionImg2ImgPipeline
import streamlit as st
import comfyui as cui
from transformers import CLIPTextModel, CLIPTokenizer
from datasets import load_dataset
import logging
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Import necessary libraries
#       2 import torch
# ----> 3 from diffusers import StableDiffusionPipeline, StableDiffusionImg2ImgPipeline
#       4 import streamlit as st
#       5 import comfyui as cui
#
# File <frozen importlib._bootstrap>:1412, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\Users\Mit\AppData\Local\Programs\Python\Python312\Lib\site-packages\diffusers\utils\import_utils.py:911, in _LazyModule.__getattr__(self, name)
#     909 elif name in self._class_to_module.keys():
#     910     module = self._get_module(self._class_to_module[name])
# --> 911     value = getattr(module, name)
#     912 else:
#     913     raise AttributeError(f"module {self.__name__} has no attribute {name}")
#
# File c:\Users\Mit\AppData\Local\Programs\Python\Python312\Lib\site-packages\diffusers\utils\import_utils.py:911, in _LazyModule.__getattr__(self, name)
#     909 elif name in self._class_to_module.keys():
#     910     module = self._get_module(self._class_to_module[name])
# --> 911     value = getattr(module, name)
#     912 else:
#     913     raise AttributeError(f"module {self.__name__} has no attribute {name}")
#
# File c:\Users\Mit\AppData\Local\Programs\Python\Python312\Lib\site-packages\diffusers\utils\import_utils.py:910, in _LazyModule.__getattr__(self, name)
#     908     value = self._get_module(name)
#     909 elif name in self._class_to_module.keys():
# --> 910     module = self._get_module(self._class_to_module[name])
#     911     value = getattr(module, name)
#     912 else:
#
# File c:\Users\Mit\AppData\Local\Programs\Python\Python312\Lib\site-packages\diffusers\utils\import_utils.py:920, in _LazyModule._get_module(self, module_name)
#     918 def _get_module(self, module_name: str):
#     919     try:
# --> 920         return importlib.import_module("." + module_name, self.__name__)
#     921     except Exception as e:
#     922         raise RuntimeError(
#     923             f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#     924             f" traceback):\n{e}"
#     925         ) from e
#
# File c:\Users\Mit\AppData\Local\Programs\Python\Python312\Lib\importlib\__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Users\Mit\AppData\Local\Programs\Python\Python312\Lib\site-packages\diffusers\pipelines\stable_diffusion\pipeline_stable_diffusion.py:19
#      17 import torch
#      18 from packaging import version
# ---> 19 from transformers import CLIPImageProcessor, CLIPTextModel, CLIPTokenizer, CLIPVisionModelWithProjection
#      21 from ...callbacks import MultiPipelineCallbacks, PipelineCallback
#      22 from ...configuration_utils import FrozenDict
#
# File <frozen importlib._bootstrap>:1412, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\Users\Mit\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\utils\import_utils.py:1806, in _LazyModule.__getattr__(self, name)
#    1804 elif name in self._class_to_module.keys():
#    1805     module = self._get_module(self._class_to_module[name])
# -> 1806     value = getattr(module, name)
#    1807 elif name in self._modules:
#    1808     value = self._get_module(name)
#
# File c:\Users\Mit\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\utils\import_utils.py:1805, in _LazyModule.__getattr__(self, name)
#    1803     value = Placeholder
#    1804 elif name in self._class_to_module.keys():
# -> 1805     module = self._get_module(self._class_to_module[name])
#    1806     value = getattr(module, name)
#    1807 elif name in self._modules:
#
# File c:\Users\Mit\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\utils\import_utils.py:1817, in _LazyModule._get_module(self, module_name)
#    1815 def _get_module(self, module_name: str):
#    1816     try:
# -> 1817         return importlib.import_module("." + module_name, self.__name__)
#    1818     except Exception as e:
#    1819         raise RuntimeError(
#    1820             f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1821             f" traceback):\n{e}"
#    1822         ) from e
#
# File c:\Users\Mit\AppData\Local\Programs\Python\Python312\Lib\importlib\__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Users\Mit\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\models\clip\image_processing_clip.py:21
#      17 from typing import Dict, List, Optional, Union
#      19 import numpy as np
# ---> 21 from ...image_processing_utils import BaseImageProcessor, BatchFeature, get_size_dict
#      22 from ...image_transforms import (
#      23     convert_to_rgb,
#      24     get_resize_output_image_size,
#      25     resize,
#      26     to_channel_dimension_format,
#      27 )
#      28 from ...image_utils import (
#      29     OPENAI_CLIP_MEAN,
#      30     OPENAI_CLIP_STD,
#    (...)
#      40     validate_preprocess_arguments,
#      41 )
#
# File c:\Users\Mit\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\image_processing_utils.py:21
#      18 import numpy as np
#      20 from .image_processing_base import BatchFeature, ImageProcessingMixin
# ---> 21 from .image_transforms import center_crop, normalize, rescale
#      22 from .image_utils import ChannelDimension
#      23 from .utils import logging
#
# File c:\Users\Mit\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\image_transforms.py:22
#      18 from typing import Iterable, List, Optional, Tuple, Union
#      20 import numpy as np
# ---> 22 from .image_utils import (
#      23     ChannelDimension,
#      24     ImageInput,
#      25     get_channel_dimension_axis,
#      26     get_image_size,
#      27     infer_channel_dimension_format,
#      28 )
#      29 from .utils import ExplicitEnum, TensorType, is_jax_tensor, is_tf_tensor, is_torch_tensor
#      30 from .utils.import_utils import (
#      31     is_flax_available,
#      32     is_tf_available,
#    (...)
#      37     requires_backends,
#      38 )
#
# File c:\Users\Mit\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\image_utils.py:59
#      56         PILImageResampling = PIL.Image
#      58     if is_torchvision_available():
# ---> 59         from torchvision.transforms import InterpolationMode
#      61         pil_torch_interpolation_mapping = {
#      62             PILImageResampling.NEAREST: InterpolationMode.NEAREST,
#      63             PILImageResampling.BOX: InterpolationMode.BOX,
#    (...)
#      67             PILImageResampling.LANCZOS: InterpolationMode.LANCZOS,
#      68         }
#      71 if TYPE_CHECKING:
#
# File c:\Users\Mit\AppData\Local\Programs\Python\Python312\Lib\site-packages\torchvision\__init__.py:10
#       7 # Don't re-order these, we need to load the _C extension (done when importing
#       8 # .extensions) before entering _meta_registrations.
#       9 from .extension import _HAS_OPS  # usort:skip
# ---> 10 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils  # usort:skip
#      12 try:
#      13     from .version import __version__  # noqa: F401
#
# File c:\Users\Mit\AppData\Local\Programs\Python\Python312\Lib\site-packages\torchvision\models\__init__.py:2
#       1 from .alexnet import *
# ----> 2 from .convnext import *
#       3 from .densenet import *
#       4 from .efficientnet import *
#
# File c:\Users\Mit\AppData\Local\Programs\Python\Python312\Lib\site-packages\torchvision\models\convnext.py:8
#       5 from torch import nn, Tensor
#       6 from torch.nn import functional as F
# ----> 8 from ..ops.misc import Conv2dNormActivation, Permute
#       9 from ..ops.stochastic_depth import StochasticDepth
#      10 from ..transforms._presets import ImageClassification
#
# File c:\Users\Mit\AppData\Local\Programs\Python\Python312\Lib\site-packages\torchvision\ops\__init__.py:1
# ----> 1 from ._register_onnx_ops import _register_custom_op
#       2 from .boxes import (
#       3     batched_nms,
#       4     box_area,
#    (...)
#      13     remove_small_boxes,
#      14 )
#      15 from .ciou_loss import complete_box_iou_loss
#
# File c:\Users\Mit\AppData\Local\Programs\Python\Python312\Lib\site-packages\torchvision\ops\_register_onnx_ops.py:5
#       2 import warnings
#       4 import torch
# ----> 5 from torch.onnx import symbolic_opset11 as opset11
#       6 from torch.onnx.symbolic_helper import parse_args
#       8 _ONNX_OPSET_VERSION_11 = 11
#
# File c:\Users\Mit\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\onnx\__init__.py:67
#      65 from ._type_utils import JitScalarType
#      66 from .errors import OnnxExporterError
# ---> 67 from .utils import (
#      68     _run_symbolic_function,
#      69     _run_symbolic_method,
#      70     is_in_onnx_export,
#      71     register_custom_op_symbolic,
#      72     select_model_mode_for_export,
#      73     unregister_custom_op_symbolic,
#      74 )
#      77 from . import (  # usort: skip. Keep the order instead of sorting lexicographically
#      78     errors,
#      79     symbolic_caffe2,
#    (...)
#      95     utils,
#      96 )
#      99 from ._internal._exporter_legacy import (  # usort: skip. needs to be last to avoid circular import
#     100     DiagnosticOptions,
#     101     ExportOptions,
#    (...)
#     104     enable_fake_mode,
#     105 )
#
# File c:\Users\Mit\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\onnx\utils.py:25
#      23 from torch.onnx import _constants, _deprecation, errors, symbolic_helper  # noqa: F401
#      24 from torch.onnx._globals import GLOBALS
# ---> 25 from torch.onnx._internal import diagnostics, jit_utils, onnx_proto_utils, registration
#      28 __all__ = [
#      29     "is_in_onnx_export",
#      30     "select_model_mode_for_export",
#    (...)
#      40     "unregister_custom_op_symbolic",
#      41 ]
#      44 def is_in_onnx_export() -> bool:
#
# File c:\Users\Mit\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\onnx\_internal\diagnostics\__init__.py:1
# ----> 1 from ._diagnostic import (
#       2     create_export_diagnostic_context,
#       3     diagnose,
#       4     engine,
#       5     export_context,
#       6     ExportDiagnosticEngine,
#       7     TorchScriptOnnxExportDiagnostic,
#       8 )
#       9 from ._rules import rules
#      10 from .infra import levels
#
# File c:\Users\Mit\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\onnx\_internal\diagnostics\_diagnostic.py:11
#       8 from typing import TYPE_CHECKING
#      10 import torch
# ---> 11 from torch.onnx._internal.diagnostics import infra
#      12 from torch.onnx._internal.diagnostics.infra import formatter, sarif
#      13 from torch.onnx._internal.diagnostics.infra.sarif import version as sarif_version
#
# File c:\Users\Mit\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\onnx\_internal\diagnostics\infra\__init__.py:1
# ----> 1 from ._infra import (
#       2     DiagnosticOptions,
#       3     Graph,
#       4     Invocation,
#       5     Level,
#       6     levels,
#       7     Location,
#       8     Rule,
#       9     RuleCollection,
#      10     Stack,
#      11     StackFrame,
#      12     Tag,
#      13     ThreadFlowLocation,
#      14 )
#      15 from .context import Diagnostic, DiagnosticContext, RuntimeErrorWithDiagnostic
#      18 __all__ = [
#      19     "Diagnostic",
#      20     "DiagnosticContext",
#    (...)
#      33     "ThreadFlowLocation",
#      34 ]
#
# File c:\Users\Mit\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\onnx\_internal\diagnostics\infra\_infra.py:11
#       8 import logging
#       9 from typing import Mapping, Sequence
# ---> 11 from torch.onnx._internal.diagnostics.infra import formatter, sarif
#      14 class Level(enum.IntEnum):
#      15     """The level of a diagnostic.
#      16
#      17     This class is used to represent the level of a diagnostic. The levels are defined
#    (...)
#      34         Level.ERROR = logging.ERROR = 40
#      35     """
#
# File c:\Users\Mit\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\onnx\_internal\diagnostics\infra\formatter.py:10
#       7 from typing import Any, Callable, Union
#       9 from torch._logging import LazyString
# ---> 10 from torch.onnx._internal.diagnostics.infra import sarif
#      13 # A list of types in the SARIF module to support pretty printing.
#      14 # This is solely for type annotation for the functions below.
#      15 _SarifClass = Union[
#      16     sarif.SarifLog,
#      17     sarif.Run,
#      18     sarif.ReportingDescriptor,
#      19     sarif.Result,
#      20 ]
#
# File c:\Users\Mit\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\onnx\_internal\diagnostics\infra\sarif\__init__.py:6
#       4 from torch.onnx._internal.diagnostics.infra.sarif._address import Address
#       5 from torch.onnx._internal.diagnostics.infra.sarif._artifact import Artifact
# ----> 6 from torch.onnx._internal.diagnostics.infra.sarif._artifact_change import ArtifactChange
#       7 from torch.onnx._internal.diagnostics.infra.sarif._artifact_content import (
#       8     ArtifactContent,
#       9 )
#      10 from torch.onnx._internal.diagnostics.infra.sarif._artifact_location import (
#      11     ArtifactLocation,
#      12 )
#
# File c:\Users\Mit\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\onnx\_internal\diagnostics\infra\sarif\_artifact_change.py:9
#       6 import dataclasses
#       7 from typing import List, Optional
# ----> 9 from torch.onnx._internal.diagnostics.infra.sarif import (
#      10     _artifact_location,
#      11     _property_bag,
#      12     _replacement,
#      13 )
#      16 @dataclasses.dataclass
#      17 class ArtifactChange(object):
#      18     """A change to a single artifact."""
#
# File c:\Users\Mit\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\onnx\_internal\diagnostics\infra\sarif\_replacement.py:9
#       6 import dataclasses
#       7 from typing import Optional
# ----> 9 from torch.onnx._internal.diagnostics.infra.sarif import (
#      10     _artifact_content,
#      11     _property_bag,
#      12     _region,
#      13 )
#      16 @dataclasses.dataclass
#      17 class Replacement(object):
#      18     """The replacement of a single region of an artifact."""
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:995, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:1091, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1191, in get_data(self, path)
#
# KeyboardInterrupt:

# %%
# Setup logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# %%
# Load the Stable Diffusion model
model_id = "CompVis/stable-diffusion-v1-4"
device = "cuda" if torch.cuda.is_available() else "cpu"
pipe = StableDiffusionPipeline.from_pretrained(model_id)
pipe.to(device)
logger.info("Model loaded successfully")

# %%
# Fine-tune the model with user-provided data (optional)
# This step can be skipped if not needed
def fine_tune_model(data):
    # Implement fine-tuning logic here
    pass

user_data = st.file_uploader("Upload training data for fine-tuning (optional)")
if user_data is not None:
    fine_tune_model(user_data)
    logger.info("Model fine-tuned with user data")

# %%
# Create the Streamlit UI with ComfyUI integration
st.title("Advanced Image Generation with Stable Diffusion and ComfyUI")
prompt = st.text_input("Enter your prompt:", "A futuristic cityscape")
num_inference_steps = st.slider("Number of inference steps", min_value=1, max_value=100, value=50)
guidance_scale = st.slider("Guidance scale", min_value=1.0, max_value=20.0, value=7.5)

if st.button("Generate Image"):
    try:
        with st.spinner("Generating image..."):
            image = pipe(prompt, num_inference_steps=num_inference_steps, guidance_scale=guidance_scale).images[0]
            st.image(image, caption="Generated Image")
            cui.display(image)
            logger.info("Image generated successfully")
    except Exception as e:
        st.error(f"Error generating image: {e}")
        logger.error(f"Error generating image: {e}")

# %%
# Optimize the model for efficiency
pipe.enable_attention_slicing()
pipe.enable_xformers_memory_efficient_attention()
logger.info("Model optimized for efficiency")
